# %%
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier
iris = load_iris()
X = iris.data[:,2:]
y = iris.target
tree_clf = DecisionTreeClassifier(max_depth=2)
tree_clf.fit(X,y)
# Out:
# DecisionTreeClassifier(max_depth=2)

# %%
conda install pydotplus
# Out:
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\dpham\anaconda3
#
#   added / updated specs:
#     - pydotplus
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     graphviz-2.38              |       hfd603c8_2        29.3 MB
#     pydotplus-2.0.2            |             py_3          23 KB
#     ------------------------------------------------------------
#                                            Total:        29.3 MB
#
# The following NEW packages will be INSTALLED:
#
#   graphviz           pkgs/main/win-64::graphviz-2.38-hfd603c8_2
#   pydotplus          pkgs/main/noarch::pydotplus-2.0.2-py_3
#
#
#
# ...
#
# graphviz-2.38        | 29.3 MB   |            |   0%
# graphviz-2.38        | 29.3 MB   | 2          |   2%
# graphviz-2.38        | 29.3 MB   | 6          |   6%
# graphviz-2.38        | 29.3 MB   | #          |  10%
# ...

# %%
from six import StringIO
from IPython.display import Image
import pydotplus
from sklearn.tree import export_graphviz
iris_tree1 = StringIO()
export_graphviz(
                tree_clf,
                out_file=iris_tree1,
                feature_names=iris.target_names[1:],
                rounded=True,
                filled=True
)
graph = pydotplus.graph_from_dot_data(iris_tree1.getvalue())
Image(graph.create_png())

# %%
#create .dot file with name is iris_tree.dot, need webgraphviz to generate decision tree graph
#from sklearn.tree import export_graphviz
#iris_tree = StringIO()
#export_graphviz(
#                tree_clf,
#                out_file='./iris_tree.dot',
#                feature_names=iris.target_names[1:],
#                rounded=True,
#                filled=True
#)

# %%
#convert to dot file to png
#install Graphviz
#add PATH
#open cmd and go to where saved .dot file
#run this command: 
dot iris_tree.dot -Tpng -o iris_tree.png

# %%
from sklearn.tree import DecisionTreeRegressor
tree_reg = DecisionTreeRegressor(max_depth=2)
tree_reg.fit(X,y)
# Out:
# DecisionTreeRegressor(max_depth=2)

# %%
iris_tree2 = StringIO()
export_graphviz(
                tree_reg,
                out_file=iris_tree2,
                feature_names=iris.target_names[1:],
                rounded=True,
                filled=True
)
graph = pydotplus.graph_from_dot_data(iris_tree2.getvalue())
Image(graph.create_png())
